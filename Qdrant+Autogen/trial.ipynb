# %%
import autogen

# %%
from autogen.retrieve_utils import TEXT_FORMATS

# %%
config_list = [
    {
    "model":"Mistral",
    "base_url":"http://localhost:4000",
    "api_key":"NULL"
    }
]

# %%
json_data_example ="""{
      "id": "19e94978-434e-4422-b55f-33ea19a2bdda",
      "timestamp": 1704283368461,
      "type": "passive",
      "deviceConfigId": "4GWaJ9DbzYGEyUM8BhHnlShijrJvTJbURIyDhA3jaXk",
      "accessPointId": "AQL6SPO6oJSRjT3XaDF08p1pNHh83dFEXok2WmHF5rU",
      "scanData":
      {
        "entries":
        [
          {
            "bssid": "a8:bd:27:87:e6:02",
            "ssid": "#momogoboom",
            "signalStrength": -54.0,
            "channel": "11",
            "channelWidth": 20,
            "frequency": 2462,
            "beaconInterval": 0,
            "channelUtilization": 43,
            "stationCount": 3,
            "dot11nMode": "HT20",
            "dot11acMode": "NA",
            "lowestSupportedDataRate": 1.0,
            "bssidSupportedStandards": "legacy/b/g/n",
            "isMyNetwork": true,
            "signal_strength": -54.0,
            "band": 2.4,
            "beacon_interval": 0,
            "channel_utilization": 43,
            "station_count": 3,
            "dot11axMode": "NA"
          },
          {
            "bssid": "7e:27:bc:e5:55:6a",
            "ssid": "",
            "signalStrength": -63.0,
            "channel": "116",
            "channelWidth": 20,
            "frequency": 5580,
            "beaconInterval": 0,
            "dot11nMode": "HT20",
            "dot11acMode": "NA",
            "lowestSupportedDataRate": 6.0,
            "bssidSupportedStandards": "a/n",
            "isMyNetwork": false,
            "signal_strength": -63.0,
            "band": 5.0,
            "beacon_interval": 0,
            "dot11axMode": "NA"
          },
          {
            "bssid": "18:60:24:d6:ac:4b",
            "ssid": "DIRECT-4A-HP OfficeJet 4650",
            "signalStrength": -64.0,
            "channel": "11",
            "channelWidth": 20,
            "frequency": 2462,
            "beaconInterval": 0,
            "dot11nMode": "HT20",
            "dot11acMode": "NA",
            "lowestSupportedDataRate": 6.0,
            "bssidSupportedStandards": "g/n",
            "isMyNetwork": false,
            "signal_strength": -64.0,
            "band": 2.4,
            "beacon_interval": 0,
            "dot11axMode": "NA"
          },
          {
            "bssid": "a8:bd:27:87:e6:12",
            "ssid": "#momogoboom",
            "signalStrength": -58.0,
            "channel": "116",
            "channelWidth": 80,
            "frequency": 5580,
            "beaconInterval": 0,
            "channelUtilization": 34,
            "stationCount": 3,
            "dot11nMode": "HT40+",
            "dot11acMode": "VHT80",
            "dot11acCenterChannelFreqSegment0": 122,
            "dot11acCenterChannelFreqSegment1": 0,
            "lowestSupportedDataRate": 6.0,
            "bssidSupportedStandards": "a/n/ac",
            "isMyNetwork": true,
            "signal_strength": -58.0,
            "band": 5.0,
            "beacon_interval": 0,
            "channel_utilization": 34,
            "station_count": 3,
            "dot11axMode": "NA"
          },
          {
            "bssid": "a8:bd:27:87:e6:10",
            "ssid": "#momogoboom5",
            "signalStrength": -58.0,
            "channel": "116",
            "channelWidth": 80,
            "frequency": 5580,
            "beaconInterval": 0,
            "channelUtilization": 34,
            "stationCount": 5,
            "dot11nMode": "HT40+",
            "dot11acMode": "VHT80",
            "dot11acCenterChannelFreqSegment0": 122,
            "dot11acCenterChannelFreqSegment1": 0,
            "lowestSupportedDataRate": 6.0,
            "bssidSupportedStandards": "a/n/ac",
            "isMyNetwork": true,
            "signal_strength": -58.0,
            "band": 5.0,
            "beacon_interval": 0,
            "channel_utilization": 34,
            "station_count": 5,
            "dot11axMode": "NA"
          },
          {
            "bssid": "a8:bd:27:87:e6:01",
            "ssid": "#momogoboom2",
            "signalStrength": -54.0,
            "channel": "11",
            "channelWidth": 20,
            "frequency": 2462,
            "beaconInterval": 0,
            "channelUtilization": 37,
            "stationCount": 2,
            "dot11nMode": "HT20",
            "dot11acMode": "NA",
            "lowestSupportedDataRate": 1.0,
            "bssidSupportedStandards": "legacy/b/g/n",
            "isMyNetwork": true,
            "signal_strength": -54.0,
            "band": 2.4,
            "beacon_interval": 0,
            "channel_utilization": 37,
            "station_count": 2,
            "dot11axMode": "NA"
          }
        ],
        "timestamp": 1704283362498,
        "stickyFactor": 0,
        "bestNeighboringAccessPointSignalStrength": null,
        "bestNeighboringAccessPointBssid": null
      },
      "activeConnection": "wireless",
      "wifiAdapterState": "enabled",
      "vpnConnection": false,
      "restrictedNetwork": false,
      "measurements":
      [
        {
          "metric": "CHANNEL_UTILIZATION",
          "timestamp": 1704283368461,
          "target": null,
          "units": "%",
          "value": 13.0,
          "gateway": false
        },
        {
          "metric": "CLIENT_COUNT",
          "timestamp": 1704283368461,
          "target": null,
          "units": "count",
          "value": 5.0,
          "gateway": false
        },
        {
          "metric": "SEVEN_MCS",
          "timestamp": 1704283368461,
          "target": null,
          "units": "7MCS",
          "value": 9.0,
          "gateway": false
        },
        {
          "metric": "SIGNAL_STRENGTH",
          "timestamp": 1704283368461,
          "target": null,
          "units": "dBm",
          "value": -58.0,
          "gateway": false
        },
        {
          "metric": "TX_RATE",
          "timestamp": 1704283368461,
          "target": null,
          "units": "Mbps",
          "value": 866.7,
          "gateway": false
        }
      ],
      "events":
      [
        {
          "type": "CO_CHANNEL_INTERFERENCE",
          "bssid": "a8:bd:27:87:e6:10",
          "ssid": "#momogoboom5",
          "band": 5.0,
          "criticality": "WARNING",
          "target": null,
          "timestamp": 1704283368460,
          "message": "Co-channel interference detected",
          "averageChannelUtilization": 13,
          "interferingBssids":
          [
            {
              "ssid": "",
              "bssid": "7e:27:bc:e5:55:6a",
              "signalStrength": -63.0,
              "apName": null,
              "channelUtilization": null,
              "stationCount": null,
              "channelInfo":
              {
                "channel": 116,
                "frequency": 5580,
                "htMode": "NONE",
                "vhtMode": "UNKNOWN",
                "heMode": "UNKNOWN",
                "band": 5.0
              }
            }
          ],
          "channelDetails":
          {
            "channel": 116,
            "frequency": 5580,
            "htMode": "ABOVE",
            "vhtMode": "WIDTH_80_MHZ",
            "heMode": "UNKNOWN",
            "band": 5.0
          },
          "thresholds":
          {
            "enabled": true,
            "signalStrength": -85,
            "bssidsHavingBssLoad": 2,
            "averageChannelUtilization": 40,
            "criticalOverlappingBssidsOn2400MHz": 4,
            "criticalOverlappingBssidsOn5000MHz": 2,
            "criticalOverlappingBssidsOn6000MHz": 2,
            "warningOverlappingBssidsOn2400MHz": 3,
            "warningOverlappingBssidsOn5000MHz": 1,
            "warningOverlappingBssidsOn6000MHz": 1,
            "downlinkThroughputThresholds": null
          }
        }
      ]
    }"""

# %%
inferred_query = """
Do I have an interference issue where my access point is on channel 116 with channel width of 80MHz and channel utilization 
of 18% and a signal strength of -58.0 dBm and there is a nearby access point on on channel 116 with a channel width of 20MHz
and an unknown channel utilization and a signal strength of -63.0 dBm.
"""

# %%
prompt1 = (
    """
    Act as if you are working as a tech lead in a networking firm. And based on these records and the JSON logs
    you've to respond to the query and solve it. I have provided you with 1 sample Answer how it should look like: 
    """
    f"""
    Given the JSON data representing an hour's worth of Wi-Fi test data and the user query:
    The JSON Logs are {json_data_example} and the query is {inferred_query}. 
    The ideal answer should go in a phased manner. 
    After the {inferred_query} has been formed
    The answer should somewhat look like this, The flow of solving a question, Please remember this is just an example and you shouldn't repeat all queries with the same answer this is just a sample answer. Use the knowledge base to solve the query that is given to you: 
    > From the provided information, it appears that there might be an interference issue between your access point and the nearby access point on the same channel (channel 116).
    >
    > The wide channel width (80MHz) of your access point might be causing interference, especially with the nearby access point operating on a narrower channel width (20MHz). Although the signal strength of your access point is stronger (-58.0 dBm) compared to the nearby one (-63.0 dBm), the difference might not be sufficient to eliminate interference, especially if both devices are close enough to each other.
    > 
    > The channel utilization of 18% on your access point indicates that there is some activity on that channel, although it's not excessively high. However, without knowing the channel utilization of the nearby access point, it's challenging to determine the extent of interference caused.
    > 
    > To address this:
    > 
    > Change Channel or Channel Width: Consider changing the channel of your access point to a less congested one or reducing the channel width to minimize interference with the nearby access point. You can use Wi-Fi analyzer tools to identify less crowded channels.
    > 
    > Evaluate Nearby Access Point's Utilization: If possible, try to gather information about the channel utilization of the nearby access point. If it's significantly high, it could contribute to interference. Adjust your channel or settings accordingly.
    > 
    > Optimize Signal Strength: While your access point has a stronger signal, adjusting the positioning or antenna orientation might further optimize its signal strength and quality within your desired coverage area.
    > 
    > Monitor and Test: Regularly monitor the network performance after making changes to assess whether the interference has reduced and the overall performance has improved.
    > 
    > Remember, mitigating interference often involves a combination of adjusting settings, channel selection, and monitoring network performance over time to find the most effective configuration for your specific environment.
 
   """
    )

# %%
qa_problem = """
        {
          "type": "COVERAGE",
          "bssid": "a8:bd:27:87:e6:10",
          "ssid": "#momogoboom5",
          "band": 5.0,
          "criticality": "GOOD",
          "target": null,
          "timestamp": 1704284031210,
          "signalStrength": -58.0,
          "stickyFactor": 0,
          "bestAlternativeSignalStrength": null,
          "thresholds":
          {
            "enabled": true,
            "signalStrengthThresholds":
            {
              "enabled": true,
              "thresholds":
              {
                "critical": -73.0,
                "warning": -70.0
              },
              "targetHost": null,
              "band": null
            },
            "roamingThresholds":
            {
              "enabled": true,
              "thresholds":
              {
                "critical": 2.0,
                "warning": 1.0
              },
              "targetHost": null,
              "band": null,
              "signalStrengthRangeMin": -90,
              "signalStrengthRangeMax": -20,
              "roamingConfigDelta": 7,
              "roamingConfigThreshold": -70
            },
            "bestAlternativeSignalStrengthThresholds":
            {
              "enabled": true,
              "thresholds":
              {
                "critical": 0.0,
                "warning": 0.0
              },
              "targetHost": null,
              "band": null
            }
          }
        }"""

# %%
from autogen.agentchat.contrib.retrieve_assistant_agent import RetrieveAssistantAgent

assistant = RetrieveAssistantAgent(
    name="assistant",
    system_message=f"""
    As a tech lead in a networking firm, you should approach your analysis and responses by drawing insights from the
    structure and content of the sample answer in {prompt1}.
    Begin by examining the JSON data{qa_problem} to infer the user's query, and then methodically break down your response into phases.
    If the data is insufficient to answer confidently,
    clearly indicate that more context is needed or that the information is not available to provide a definitive answer.
    """,
    llm_config={
        "timeout": 600,
        "cache_seed": 42,
        "config_list": config_list
    },
)

# %%
from autogen.agentchat.contrib.qdrant_retrieve_user_proxy_agent import QdrantRetrieveUserProxyAgent
from qdrant_client import QdrantClient

ragproxyagent = QdrantRetrieveUserProxyAgent(
    name="ragproxyagent",
    human_input_mode="TERMINATE",
    max_consecutive_auto_reply=10,
    retrieve_config={
        "task": "qa",
        "docs_path": [
            ".\PDF\CWAP_WLAN_ANALYSIS.pdf",
            ".\PDF\CWNA WIRELESS NETWORK ADMIN.pdf"
        ], 
        "model": config_list[0]["model"],
        "client": QdrantClient(
                    url="https://476663d9-a978-4b06-b861-1e83efa6ace2.us-east4-0.gcp.cloud.qdrant.io:6333", 
                    api_key="J-vYZKgyVG24F3kfCnnj1nRNe31C9qPf3EgYOmRXuoGLrOFRHbQkWw",
                ),
        "embedding_model": "BAAI/bge-small-en-v1.5"
    },
    code_execution_config=False,
)

# %%
assistant.reset()


ragproxyagent.initiate_chat(
    assistant, 
    message=ragproxyagent.message_generator, 
    problem=qa_problem
)
# Out:
# No default IOStream has been set, defaulting to IOConsole.
# No default IOStream has been set, defaulting to IOConsole.
# No default IOStream has been set, defaulting to IOConsole.
# Trying to create collection.
# max_tokens is too small to fit a single line of text. Breaking this line:
# 	  ...
# Failed to split docs with must_break_at_empty_line being True, set to False.
# max_tokens is too small to fit a single line of text. Breaking this line:
# 	ffirs.indd   ii ffirs.indd   ii 4/10/2012   4:27:27 PM 4/10/2012   4:27:27 PMCWNA® ...
# Failed to split docs with must_break_at_empty_line being True, set to False.
# Model Mistral not found. Using cl100k_base encoding.
# Adding doc_id 89 to context.
# Model Mistral not found. Using cl100k_base encoding.
# Adding doc_id 363 to context.
# Model Mistral not found. Using cl100k_base encoding.
# No default IOStream has been set, defaulting to IOConsole.
# ragproxyagent (to assistant):
#
# You're a retrieve augmented chatbot. You answer user's questions based on your own knowledge and the
# context provided by the user.
# If you can't answer the question with or without the current context, you should reply exactly `UPDATE CONTEXT`.
# You must give as short an answer as possible.
#
# User's question is:
#         {
#           "type": "COVERAGE",
#           "bssid": "a8:bd:27:87:e6:10",
#           "ssid": "#momogoboom5",
#           "band": 5.0,
#           "criticality": "GOOD",
#           "target": null,
#           "timestamp": 1704284031210,
#           "signalStrength": -58.0,
#           "stickyFactor": 0,
#           "bestAlternativeSignalStrength": null,
#           "thresholds":
#           {
#             "enabled": true,
#             "signalStrengthThresholds":
#             {
#               "enabled": true,
#               "thresholds":
#               {
#                 "critical": -73.0,
#                 "warning": -70.0
#               },
#               "targetHost": null,
#               "band": null
#             },
#             "roamingThresholds":
#             {
#               "enabled": true,
#               "thresholds":
#               {
#                 "critical": 2.0,
#                 "warning": 1.0
#               },
#               "targetHost": null,
#               "band": null,
#               "signalStrengthRangeMin": -90,
#               "signalStrengthRangeMax": -20,
#               "roamingConfigDelta": 7,
#               "roamingConfigThreshold": -70
#             },
#             "bestAlternativeSignalStrengthThresholds":
#             {
#               "enabled": true,
#               "thresholds":
#               {
#                 "critical": 0.0,
#                 "warning": 0.0
#               },
#               "targetHost": null,
#               "band": null
#             }
#           }
#         }
#
# Context is:
# After finding that channel 1 has a significant source of narrowband RF interference with harmonics that fall into the channel 11 series of frequencies, Mr. Parsons tries to find th e source.  He finds that the source
# of this RF interference is a power tool that is used repeatedly throughout
# the day to repair aircraft engines.  Since this tool must be used, the alternative to discontinued use is to move the access point to channel 6.
# This change gives the client devi ces and access point the best chance of
# receiving uncorrupted frames.  After moving the access point to channel 6, performance improves dramatically, and the problem is solved.
#  Index   405
#  802.11
# control frames. see control frames
# data frames. see data frames
# MAC frame format. see MAC layer frame format
# MAC layer. see MAC layer
# management frames. see management frames
# performance. see performance impacts
# PHY layer. see PHY (physical) layer
# protocol analyzers. see protocol analyzers
# system architecture. see system architecture
# TGn (Task Group n), 358
# 802.11i/WPA2/AES, 260–65
# 802.11 protocol architecture, 24–62
# active scanning, 34–35 data rate shifting, 59
# DS (distribution system), 26–29
# error control, 58–59 integration service, 29–30
# key terms, 61
# MAC Layer, 30–33 passive scanning, 33–34
# review questions, 62–63
# services, 24–25 summary, 60
# synchronization, 35–37
# system services, 25–26
# 802.1H, 244, 374
# 802.1x/EAP
# access point security, 259–60 data protection, 80–83
# encryption overhead, 354–57
# 802.2, 372. See also  LLC (Logical Link Control) layer
# 802.3 (Ethernet)
# connections on mesh routers, 282
# frame formats, 243 frame translation and, 243–44
# LANs, 242
# LLC layer and, 373
# 802 Reference Model, 372
# A
# AAA service, 258 acceptance testing, 7
# access control, 4
# access point capable of service (QAP), 208 Access Point CF-Pollable subf ield, Capability Information
# field, 176–77
# Access Point CF-Poll Request subfield, Capability
# Information field, 176–77
# access points, 242–65
# 802.11i/WPA2/AES and, 260–65 802.1x/EAP and, 259–60
# association, 68–69 auto-channel selection, 247
# Capability Information field and, 176–79
# DS (Distribution System) and, 24
# DSS (Distribution System Service) and, 140 frame translation, 243–46
# hidden nodes, 359
# message forwarding, 242–43 node statistics, 317–19
# overview of, 242
# performance enhancements, 248–51 pre-shared keys, 259
# proprietary enhancements, 247
# QAP (access point capable of service), 208 repeaters, 255–58 RF coverage and, 4
# RF site surveys and, 6
# roaming, 70–71 security, 258
# SSIDs and, 251–55
# access timing, stations
# DIFS, 39–40
# EIFS, 40–42
# overview, 38 PIFS, 39
# SIFS, 38–39
# ACK (acknowledgement), 200–201 acknowledgement (ACK), 200–201
# active scanning, 34–35
# address fields, MAC layer, 146–50 Ad Hoc stations, 95–96
# Ad Hoc WLANs, 114
# adjacent channels, 123, 360–63 AES algorithm
# 802.11i/WPA2/AES, 260–65
# CCMP and, 79–80, 258 pre-shared keys and, 259
# protocol analyzers and, 282–83
# AGC (automatic gain control), 229–30 agents, SNMP, 382 AID (association identifier)
# association process and, 31
# in Association Response frame, 161 Duration/ID field and, 144–46
# field in frame body, 172
# AirDefense
# alarms, 342
# dashboard, 339
# live views, 345 network maps, 344
# reports, 343
# Airespace Networks, WLAN positioning system, 366 AirMagnet
# dashboard, 340
# filters, 332 frame decoding, 314 406   Index
#
#  hardware probe, 337
# Laptop Trio, 13
# live views, 345
# monitoring, 341 performance alarms, 330
# reports, 335, 341
# security alarms, 330 start screen and scanning configuration, 304
# AiroPeek NX
# expert feature, 325 filters, 334
# frames captured on adjacent channel, 363
# peer maps, 327
# alarms
# distributed analyzers, 340–43
# event, 331
# laptop/handheld analyzer, 329–31 performance, 330
# security, 330
# analysis. See also  WLAN analysis
# benefits of, 2–3
# channel analysis, 305, 319–20
# conversation analysis, 320–24 performance analysis, 11
# propagation analysis, 10–11
# security analysis, 11–12 wireless mesh networks, 283–86
# Announcement Traffic Indicati on Message (ATIM), 95–96,
# 167
# antennas, protocol analyzers, 359
# ARP frames, 245–46
# ARQ (Automatic Repeat Request), 379 Aruba Networks, WLAN positioning system, 366
# association identifier. See AID (association identifier)
# association process, MAC Layer, 31, 68–69 Association Request frames, 69, 160–61, 170
# Association Response frames, 69, 161, 170
# ATIM (Announcement Traffic Indication Message), 95–96,
# 167
# authentication, 66–68
# IPSec, 272–75
# Link layer (layer 2) security and, 258 MAC layer, 31
# open system, 66–67
# PACs (protected access credentials), 354 PPTP VPN connection and, 268
# RADIUS, 291–93
# shared keys and, 67–68
# Authentication Algorithm Number field, frame body, 172–
# 73
# Authentication frame, 167–68, 170 Authentication Transaction Sequence Number field, 173–
# 74
# auto-channel selection, access points, 247 automatic gain control (AGC), 229–30 Automatic Repeat Request (ARQ), 379
# basic and supported rates, 283–284
# roaming and, 284
# terminating, 286association identifier (AID), 282, 297
# ATEX directives, 138ATIM frame, 299attacks, 470–486 . See also  intrusion monitoring
# authentication, 478–480
# denial of service (DoS), 483–484
# eavesdropping, 475–478
# encryption cracking, 478
# MAC spoofing, 480–481
# management interface exploits, 481–482
# peer-to-peer, 474–475
# rogue wireless devices, 471–473 , 472
# social engineering, 484–485
# vendor-specific, 484
# wireless hijacking, 482–483
# attenuation (loss), 35–36, 40, 49–51 , 92
# coaxial cable chart, 142and distance, 38due to free space path loss, 52precipitation impact, 421–422
# attenuators, for antennas, 144–145
# ATU (African Telecommunications
# Union), 6
# authentication, 167, 280–281
# and association states, 282–283 , 283
# and authorization, 442
# to captive portal, 461deauthentication, 287
# in enterprise, 453
# for hotspot providers, 366legacy, 435
# legacy 802.11 technology, 435
# mutual, 483in robust security, 442
# tunneled, 479
# authentication and key management (AKM)
# services, 442
# authentication and key management protocol
# (AKMP), 442
# authentication attacks, 478–480
# authentication, authorization, and accounting
# (AAA), 433–434
# authentication server (AS), in 802.1X
# framework, 445
# authenticator, in 802.1X
# framework, 445
# authorization, 433
# in robust security, 442
# bindex.indd   682 bindex.indd   682 4/10/2012   4:32:45 PM 4/10/2012   4:32:45 PMAuto MDI-X (automatic crossover) – Broadcast SSID  683
# Auto MDI-X (automatic crossover), 573
# automatic power save delivery (APSD), 300automatic rate selection, 398autonomous access points, 226
# WNMS server for central
# management, 326
# autonomous WLAN architecture, 324–325
# azimuth charts (H-plane), 105–106 ,
# 107, 108
# for omnidirectional antenna, 114
# B
# B/G/ mode, for access point, 163B-only mode, for access point, 162baby monitors, 2.4 GHz frequency band
# use by, 192
# background noise, 53, 87, 539. See also  signal-to-
# noise ratio (SNR)
# network degradation from, 533
# Background priority access with
# WMM, 259
# BackTrack, 485backward compatibility for legacy devices,
# determining need for, 508
# band steering, 302–303
# bandwidth
# expectations for, 505vs. throughput, 214–215
# bar code scanners, 316Barker code, 90, 160, 203, 204basic service area (BSA), 233–234 , 234
# basic service set (BSS), 225, 232, 232–233
# communication problems within, 393
# basic service set identifier (BSSID), 233, 233
# virtual, 330, 414–415
# battery-operated client stations, power
# management, 296–302
# battery pack, for site survey, 544–545battery power, WMM-PS for
#  conserving, 13
# beacon management frame. See beacons
# beacons, 165, 276–279 , 298
# active scanning, 278, 278–279
# passive scanning, 277, 277–278
# viewing, 276–277
# beam divergence, 51beamformee, 595
# beamforming, 122
# dynamic, 123, 123–124
# static, 122, 123
# transmit (TxBF), 124, 588, 593–595 , 594
# beamsteering, 123beamwidth, 110–111 , 111, 112
# and Fresnel zone size, 128
# behavior analysis, 486bel, 71
# formula for, 72
# bending of RF signal, 46Berkeley Varitronics Systems, 386Best Effort priority access with WMM, 259bidirectional amplifiers, 144bill of materials (BOM), 517binary phase shift keying (BPSK), 206binoculars, for site survey, 545, 547BIP (Broadcast/Multicast Integrity Protocol), 172bit-flipping attack, 438bits, 17, 269block acknowledgment, 257, 258, 609, 609
# blogs, on Wi-Fi, 24blueprints
# for site survey, 513–514, 544vector graphic formats of, 551
# Bluetooth, 155, 160
# all-band interference from, 385interference from, 534in wireless personal area network, 224
# bottleneck, WLAN controller as, 332bounce. See reflection
# bounded medium, 32BPSK (binary phase shift keying), 206brick wall, and attenuation, 50bridge mode, for access point, 240Bridged Virtual Interface (BVI), 324bridges
# for building-to-building connectivity, 361
# point-to-multipoint WLAN, 447
# wireless, for mobile office, 363wireless LAN, 339, 339–341
# broadband wireless access, 223Broadband Wireless Access Working
# Group, 155
# Broadcast/Multicast Integrity Protocol
# (BIP), 172
# Broadcast SSID, for access point, 439
# bindex.indd   683 bindex.indd   683 4/10/2012   4:32:46 PM 4/10/2012   4:32:46 PM684 broadcast traffic – CITEL (Inter-American Telecommunication Commission)
# broadcast traffic, 298
# Broadcom Wi-Fi radio, 316, 317
# BSA (basic service area), 233–234 , 234
# BSS (basic service set), 225, 232, 232–233
# communication problems within, 393
# BSSID (basic service set identifier),
# 233, 233
# virtual, 330, 414–415
# buffered data
# roaming and, 180, 180
# station notification, 299
# buffered unicast frame, 298buildings, bridge to connect, 361
# BVI (Bridged Virtual Interface), 324byte, 269
# C
# cables
# for antennas, 141–142
# loss calculations, 548and signal loss, 135UV/sun damage to, 422
# CACE Technologies, AirPcap, 404, 405
# calculators, for site survey, 547cancellation of signal, 54capacity performance, in site survey, 530capacity, vs. coverage, troubleshooting, 416–418 ,
# 417
# captive portal, 366, 367, 460–462 , 461
# --------------------------------------------------------------------------------
# No default IOStream has been set, defaulting to IOConsole.
# No default IOStream has been set, defaulting to IOConsole.
