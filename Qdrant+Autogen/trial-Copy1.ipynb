# %%
import autogen

# %%
config_list = [
    {
    "model":"Llama3",
    "base_url":"http://localhost:4000",
    "api_key":"NULL"
    }
]

# %% [markdown]
# json_example = """{
#       "id": "19e94978-434e-4422-b55f-33ea19a2bdda",
#       "timestamp": 1704283368461,
#       "type": "passive",
#       "deviceConfigId": "4GWaJ9DbzYGEyUM8BhHnlShijrJvTJbURIyDhA3jaXk",
#       "accessPointId": "AQL6SPO6oJSRjT3XaDF08p1pNHh83dFEXok2WmHF5rU",
#       "scanData":
#       {
#         "entries":
#         [
#           {
#             "bssid": "a8:bd:27:87:e6:02",
#             "ssid": "#momogoboom",
#             "signalStrength": -54.0,
#             "channel": "11",
#             "channelWidth": 20,
#             "frequency": 2462,
#             "beaconInterval": 0,
#             "channelUtilization": 43,
#             "stationCount": 3,
#             "dot11nMode": "HT20",
#             "dot11acMode": "NA",
#             "lowestSupportedDataRate": 1.0,
#             "bssidSupportedStandards": "legacy/b/g/n",
#             "isMyNetwork": true,
#             "signal_strength": -54.0,
#             "band": 2.4,
#             "beacon_interval": 0,
#             "channel_utilization": 43,
#             "station_count": 3,
#             "dot11axMode": "NA"
#           },
#           {
#             "bssid": "7e:27:bc:e5:55:6a",
#             "ssid": "",
#             "signalStrength": -63.0,
#             "channel": "116",
#             "channelWidth": 20,
#             "frequency": 5580,
#             "beaconInterval": 0,
#             "dot11nMode": "HT20",
#             "dot11acMode": "NA",
#             "lowestSupportedDataRate": 6.0,
#             "bssidSupportedStandards": "a/n",
#             "isMyNetwork": false,
#             "signal_strength": -63.0,
#             "band": 5.0,
#             "beacon_interval": 0,
#             "dot11axMode": "NA"
#           },
#           {
#             "bssid": "18:60:24:d6:ac:4b",
#             "ssid": "DIRECT-4A-HP OfficeJet 4650",
#             "signalStrength": -64.0,
#             "channel": "11",
#             "channelWidth": 20,
#             "frequency": 2462,
#             "beaconInterval": 0,
#             "dot11nMode": "HT20",
#             "dot11acMode": "NA",
#             "lowestSupportedDataRate": 6.0,
#             "bssidSupportedStandards": "g/n",
#             "isMyNetwork": false,
#             "signal_strength": -64.0,
#             "band": 2.4,
#             "beacon_interval": 0,
#             "dot11axMode": "NA"
#           },
#           {
#             "bssid": "a8:bd:27:87:e6:12",
#             "ssid": "#momogoboom",
#             "signalStrength": -58.0,
#             "channel": "116",
#             "channelWidth": 80,
#             "frequency": 5580,
#             "beaconInterval": 0,
#             "channelUtilization": 34,
#             "stationCount": 3,
#             "dot11nMode": "HT40+",
#             "dot11acMode": "VHT80",
#             "dot11acCenterChannelFreqSegment0": 122,
#             "dot11acCenterChannelFreqSegment1": 0,
#             "lowestSupportedDataRate": 6.0,
#             "bssidSupportedStandards": "a/n/ac",
#             "isMyNetwork": true,
#             "signal_strength": -58.0,
#             "band": 5.0,
#             "beacon_interval": 0,
#             "channel_utilization": 34,
#             "station_count": 3,
#             "dot11axMode": "NA"
#           },
#           {
#             "bssid": "a8:bd:27:87:e6:10",
#             "ssid": "#momogoboom5",
#             "signalStrength": -58.0,
#             "channel": "116",
#             "channelWidth": 80,
#             "frequency": 5580,
#             "beaconInterval": 0,
#             "channelUtilization": 34,
#             "stationCount": 5,
#             "dot11nMode": "HT40+",
#             "dot11acMode": "VHT80",
#             "dot11acCenterChannelFreqSegment0": 122,
#             "dot11acCenterChannelFreqSegment1": 0,
#             "lowestSupportedDataRate": 6.0,
#             "bssidSupportedStandards": "a/n/ac",
#             "isMyNetwork": true,
#             "signal_strength": -58.0,
#             "band": 5.0,
#             "beacon_interval": 0,
#             "channel_utilization": 34,
#             "station_count": 5,
#             "dot11axMode": "NA"
#           },
#           {
#             "bssid": "a8:bd:27:87:e6:01",
#             "ssid": "#momogoboom2",
#             "signalStrength": -54.0,
#             "channel": "11",
#             "channelWidth": 20,
#             "frequency": 2462,
#             "beaconInterval": 0,
#             "channelUtilization": 37,
#             "stationCount": 2,
#             "dot11nMode": "HT20",
#             "dot11acMode": "NA",
#             "lowestSupportedDataRate": 1.0,
#             "bssidSupportedStandards": "legacy/b/g/n",
#             "isMyNetwork": true,
#             "signal_strength": -54.0,
#             "band": 2.4,
#             "beacon_interval": 0,
#             "channel_utilization": 37,
#             "station_count": 2,
#             "dot11axMode": "NA"
#           }
#         ],
#         "timestamp": 1704283362498,
#         "stickyFactor": 0,
#         "bestNeighboringAccessPointSignalStrength": null,
#         "bestNeighboringAccessPointBssid": null
#       },
#       "activeConnection": "wireless",
#       "wifiAdapterState": "enabled",
#       "vpnConnection": false,
#       "restrictedNetwork": false,
#       "measurements":
#       [
#         {
#           "metric": "CHANNEL_UTILIZATION",
#           "timestamp": 1704283368461,
#           "target": null,
#           "units": "%",
#           "value": 13.0,
#           "gateway": false
#         },
#         {
#           "metric": "CLIENT_COUNT",
#           "timestamp": 1704283368461,
#           "target": null,
#           "units": "count",
#           "value": 5.0,
#           "gateway": false
#         },
#         {
#           "metric": "SEVEN_MCS",
#           "timestamp": 1704283368461,
#           "target": null,
#           "units": "7MCS",
#           "value": 9.0,
#           "gateway": false
#         },
#         {
#           "metric": "SIGNAL_STRENGTH",
#           "timestamp": 1704283368461,
#           "target": null,
#           "units": "dBm",
#           "value": -58.0,
#           "gateway": false
#         },
#         {
#           "metric": "TX_RATE",
#           "timestamp": 1704283368461,
#           "target": null,
#           "units": "Mbps",
#           "value": 866.7,
#           "gateway": false
#         }
#       ],
#       "events":
#       [
#         {
#           "type": "CO_CHANNEL_INTERFERENCE",
#           "bssid": "a8:bd:27:87:e6:10",
#           "ssid": "#momogoboom5",
#           "band": 5.0,
#           "criticality": "WARNING",
#           "target": null,
#           "timestamp": 1704283368460,
#           "message": "Co-channel interference detected",
#           "averageChannelUtilization": 13,
#           "interferingBssids":
#           [
#             {
#               "ssid": "",
#               "bssid": "7e:27:bc:e5:55:6a",
#               "signalStrength": -63.0,
#               "apName": null,
#               "channelUtilization": null,
#               "stationCount": null,
#               "channelInfo":
#               {
#                 "channel": 116,
#                 "frequency": 5580,
#                 "htMode": "NONE",
#                 "vhtMode": "UNKNOWN",
#                 "heMode": "UNKNOWN",
#                 "band": 5.0
#               }
#             }
#           ],
#           "channelDetails":
#           {
#             "channel": 116,
#             "frequency": 5580,
#             "htMode": "ABOVE",
#             "vhtMode": "WIDTH_80_MHZ",
#             "heMode": "UNKNOWN",
#             "band": 5.0
#           },
#           "thresholds":
#           {
#             "enabled": true,
#             "signalStrength": -85,
#             "bssidsHavingBssLoad": 2,
#             "averageChannelUtilization": 40,
#             "criticalOverlappingBssidsOn2400MHz": 4,
#             "criticalOverlappingBssidsOn5000MHz": 2,
#             "criticalOverlappingBssidsOn6000MHz": 2,
#             "warningOverlappingBssidsOn2400MHz": 3,
#             "warningOverlappingBssidsOn5000MHz": 1,
#             "warningOverlappingBssidsOn6000MHz": 1,
#             "downlinkThroughputThresholds": null
#           }
#         }
#       ]
#     }
#
#
#
# """

# %% [markdown]
# inferred_query = f""" How can I remediate an interference issue where my access point is on
# channel 116 with channel width of 80MHz and channel utilization of 18%
# and a signal strength of -58.0 dBm and there is a nearby access point on
# on channel 116 with a channel width of 20MHz and an unknown channel utilization
# and a signal strength of -63.0 dBm."""

# %% [markdown]
# modal_answer = f"""
# It sounds like you're dealing with an interference problem between your access point and a nearby one on the same channel. Here are steps you can take to remediate the issue:
#
# Change Channels: If feasible, consider changing the channel of your access point. Since both are on the same channel (116), they might be interfering with each other. Look for a less congested channel using Wi-Fi analyzer tools. Channels 36, 40, 44, or others in the 5GHz range might offer less interference.
#
# Adjust Channel Width: If you can't change the channel, try adjusting the channel width of your access point. Reducing the channel width from 80MHz to 40MHz or even 20MHz might reduce interference and overlap with the nearby access point.
#
# Evaluate Channel Utilization: Try to gather information about the channel utilization of the nearby access point. If possible, use Wi-Fi analyzer tools or network monitoring software to assess its usage. If it's high, it might further indicate the need to switch to a less congested channel.
#
# Optimize Signal Strength: Your access point has a stronger signal (-58.0 dBm) compared to the nearby one (-63.0 dBm), which is good. If you can't change channels or adjust settings, consider optimizing your access point's positioning or antenna orientation to enhance signal strength and quality in your intended coverage area.
#
# Consider Interference Sources: Identify other potential sources of interference besides the nearby access point. These could include neighboring networks, electronic devices, or physical obstacles. Try to mitigate these factors to improve your Wi-Fi performance.
#
# Consult with Network Experts: If the issue persists or seems complex, consider consulting with network specialists or IT professionals who specialize in wireless network setups. They may conduct a thorough analysis and provide specific recommendations tailored to your environment.
#
# Remember, Wi-Fi performance can be affected by various factors, and sometimes it's a matter of trial and error to find the best settings for your specific environment. Regular monitoring and adjustments can help maintain optimal network performance.
# """

# %%
from autogen.agentchat.contrib.retrieve_assistant_agent import RetrieveAssistantAgent

assistant = RetrieveAssistantAgent(
    name="assistant",
    system_message=f"""
You are a helpful assistant.but before answering, you ask me 'UPDATE CONTEXT' and wait for reply 
    """,
    llm_config={
        "timeout": 600,
        "cache_seed": 42,
        "config_list": config_list
    },
)

# %%
qa_problem = """{
      "id": "19e94978-434e-4422-b55f-33ea19a2bdda",
      "timestamp": 1704283368461,
      "type": "passive",
      "deviceConfigId": "4GWaJ9DbzYGEyUM8BhHnlShijrJvTJbURIyDhA3jaXk",
      "accessPointId": "AQL6SPO6oJSRjT3XaDF08p1pNHh83dFEXok2WmHF5rU",
      "scanData":
      {
        "entries":
        [
          {
            "bssid": "a8:bd:27:87:e6:02",
            "ssid": "#momogoboom",
            "signalStrength": -54.0,
            "channel": "11",
            "channelWidth": 20,
            "frequency": 2462,
            "beaconInterval": 0,
            "channelUtilization": 43,
            "stationCount": 3,
            "dot11nMode": "HT20",
            "dot11acMode": "NA",
            "lowestSupportedDataRate": 1.0,
            "bssidSupportedStandards": "legacy/b/g/n",
            "isMyNetwork": true,
            "signal_strength": -54.0,
            "band": 2.4,
            "beacon_interval": 0,
            "channel_utilization": 43,
            "station_count": 3,
            "dot11axMode": "NA"
          },
          {
            "bssid": "7e:27:bc:e5:55:6a",
            "ssid": "",
            "signalStrength": -63.0,
            "channel": "116",
            "channelWidth": 20,
            "frequency": 5580,
            "beaconInterval": 0,
            "dot11nMode": "HT20",
            "dot11acMode": "NA",
            "lowestSupportedDataRate": 6.0,
            "bssidSupportedStandards": "a/n",
            "isMyNetwork": false,
            "signal_strength": -63.0,
            "band": 5.0,
            "beacon_interval": 0,
            "dot11axMode": "NA"
          },
          {
            "bssid": "18:60:24:d6:ac:4b",
            "ssid": "DIRECT-4A-HP OfficeJet 4650",
            "signalStrength": -64.0,
            "channel": "11",
            "channelWidth": 20,
            "frequency": 2462,
            "beaconInterval": 0,
            "dot11nMode": "HT20",
            "dot11acMode": "NA",
            "lowestSupportedDataRate": 6.0,
            "bssidSupportedStandards": "g/n",
            "isMyNetwork": false,
            "signal_strength": -64.0,
            "band": 2.4,
            "beacon_interval": 0,
            "dot11axMode": "NA"
          },
          {
            "bssid": "a8:bd:27:87:e6:12",
            "ssid": "#momogoboom",
            "signalStrength": -58.0,
            "channel": "116",
            "channelWidth": 80,
            "frequency": 5580,
            "beaconInterval": 0,
            "channelUtilization": 34,
            "stationCount": 3,
            "dot11nMode": "HT40+",
            "dot11acMode": "VHT80",
            "dot11acCenterChannelFreqSegment0": 122,
            "dot11acCenterChannelFreqSegment1": 0,
            "lowestSupportedDataRate": 6.0,
            "bssidSupportedStandards": "a/n/ac",
            "isMyNetwork": true,
            "signal_strength": -58.0,
            "band": 5.0,
            "beacon_interval": 0,
            "channel_utilization": 34,
            "station_count": 3,
            "dot11axMode": "NA"
          },
          {
            "bssid": "a8:bd:27:87:e6:10",
            "ssid": "#momogoboom5",
            "signalStrength": -58.0,
            "channel": "116",
            "channelWidth": 80,
            "frequency": 5580,
            "beaconInterval": 0,
            "channelUtilization": 34,
            "stationCount": 5,
            "dot11nMode": "HT40+",
            "dot11acMode": "VHT80",
            "dot11acCenterChannelFreqSegment0": 122,
            "dot11acCenterChannelFreqSegment1": 0,
            "lowestSupportedDataRate": 6.0,
            "bssidSupportedStandards": "a/n/ac",
            "isMyNetwork": true,
            "signal_strength": -58.0,
            "band": 5.0,
            "beacon_interval": 0,
            "channel_utilization": 34,
            "station_count": 5,
            "dot11axMode": "NA"
          },
          {
            "bssid": "a8:bd:27:87:e6:01",
            "ssid": "#momogoboom2",
            "signalStrength": -54.0,
            "channel": "11",
            "channelWidth": 20,
            "frequency": 2462,
            "beaconInterval": 0,
            "channelUtilization": 37,
            "stationCount": 2,
            "dot11nMode": "HT20",
            "dot11acMode": "NA",
            "lowestSupportedDataRate": 1.0,
            "bssidSupportedStandards": "legacy/b/g/n",
            "isMyNetwork": true,
            "signal_strength": -54.0,
            "band": 2.4,
            "beacon_interval": 0,
            "channel_utilization": 37,
            "station_count": 2,
            "dot11axMode": "NA"
          }
        ],
        "timestamp": 1704283362498,
        "stickyFactor": 0,
        "bestNeighboringAccessPointSignalStrength": null,
        "bestNeighboringAccessPointBssid": null
      },
      "activeConnection": "wireless",
      "wifiAdapterState": "enabled",
      "vpnConnection": false,
      "restrictedNetwork": false,
      "measurements":
      [
        {
          "metric": "CHANNEL_UTILIZATION",
          "timestamp": 1704283368461,
          "target": null,
          "units": "%",
          "value": 13.0,
          "gateway": false
        },
        {
          "metric": "CLIENT_COUNT",
          "timestamp": 1704283368461,
          "target": null,
          "units": "count",
          "value": 5.0,
          "gateway": false
        },
        {
          "metric": "SEVEN_MCS",
          "timestamp": 1704283368461,
          "target": null,
          "units": "7MCS",
          "value": 9.0,
          "gateway": false
        },
        {
          "metric": "SIGNAL_STRENGTH",
          "timestamp": 1704283368461,
          "target": null,
          "units": "dBm",
          "value": -58.0,
          "gateway": false
        },
        {
          "metric": "TX_RATE",
          "timestamp": 1704283368461,
          "target": null,
          "units": "Mbps",
          "value": 866.7,
          "gateway": false
        }
      ],
      "events":
      [
        {
          "type": "CO_CHANNEL_INTERFERENCE",
          "bssid": "a8:bd:27:87:e6:10",
          "ssid": "#momogoboom5",
          "band": 5.0,
          "criticality": "WARNING",
          "target": null,
          "timestamp": 1704283368460,
          "message": "Co-channel interference detected",
          "averageChannelUtilization": 13,
          "interferingBssids":
          [
            {
              "ssid": "",
              "bssid": "7e:27:bc:e5:55:6a",
              "signalStrength": -63.0,
              "apName": null,
              "channelUtilization": null,
              "stationCount": null,
              "channelInfo":
              {
                "channel": 116,
                "frequency": 5580,
                "htMode": "NONE",
                "vhtMode": "UNKNOWN",
                "heMode": "UNKNOWN",
                "band": 5.0
              }
            }
          ],
          "channelDetails":
          {
            "channel": 116,
            "frequency": 5580,
            "htMode": "ABOVE",
            "vhtMode": "WIDTH_80_MHZ",
            "heMode": "UNKNOWN",
            "band": 5.0
          },
          "thresholds":
          {
            "enabled": true,
            "signalStrength": -85,
            "bssidsHavingBssLoad": 2,
            "averageChannelUtilization": 40,
            "criticalOverlappingBssidsOn2400MHz": 4,
            "criticalOverlappingBssidsOn5000MHz": 2,
            "criticalOverlappingBssidsOn6000MHz": 2,
            "warningOverlappingBssidsOn2400MHz": 3,
            "warningOverlappingBssidsOn5000MHz": 1,
            "warningOverlappingBssidsOn6000MHz": 1,
            "downlinkThroughputThresholds": null
          }
        }
      ]
    }


     Do I have an interference issue where my access point is on channel 116 with channel width of 80MHz and channel utilization of 18% and a signal strength of 
     -58.0 dBm and there is a nearby access point on on channel 116 with a channel width of 20MHz and an unknown channel utilization and a signal strength of -63.0 dBm.

"""

# %%
from autogen.agentchat.contrib.qdrant_retrieve_user_proxy_agent import QdrantRetrieveUserProxyAgent
from qdrant_client import QdrantClient

ragproxyagent = QdrantRetrieveUserProxyAgent(
    name="ragproxyagent",
    human_input_mode="TERMINATE",
    max_consecutive_auto_reply=10,
    retrieve_config={
        "task": "qa",
        "docs_path": [
            ".\PDF\CWAP_WLAN_ANALYSIS.pdf",
            ".\PDF\CWNA WIRELESS NETWORK ADMIN.pdf"
        ], 
        "model": config_list[0]["model"],
        "client": QdrantClient(
                    url="https://476663d9-a978-4b06-b861-1e83efa6ace2.us-east4-0.gcp.cloud.qdrant.io:6333", 
                    api_key="J-vYZKgyVG24F3kfCnnj1nRNe31C9qPf3EgYOmRXuoGLrOFRHbQkWw",
                ),
        "embedding_model": "BAAI/bge-small-en-v1.5"
    },
    code_execution_config=False,
)

# %%
assistant.reset()

ragproxyagent.initiate_chat(
    assistant, 
    message=ragproxyagent.message_generator, 
    problem="hi how are you feeling today"
)
# Out:
# No default IOStream has been set, defaulting to IOConsole.
# No default IOStream has been set, defaulting to IOConsole.
# No default IOStream has been set, defaulting to IOConsole.
# Model Llama3 not found. Using cl100k_base encoding.
# Adding doc_id 10 to context.
# Model Llama3 not found. Using cl100k_base encoding.
# Adding doc_id 100 to context.
# Model Llama3 not found. Using cl100k_base encoding.
# No default IOStream has been set, defaulting to IOConsole.
# ragproxyagent (to assistant):
#
# You're a retrieve augmented chatbot. You answer user's questions based on your own knowledge and the
# context provided by the user.
# If you can't answer the question with or without the current context, you should reply exactly `UPDATE CONTEXT`.
# You must give as short an answer as possible.
#
# User's question is: hi how are you feeling today
#
# Context is:
# There are very few times in the course of human history when it's been evident that a new technology would dramatically change the way society functions.  What if you knew where the automotive industry was heading when Carl Benz championed the internal combustion engine in his 3-
# wheeled car in 1885.  What if yo u could have foreseen the aviation
# industry when the Wright's flew at Kitty Hawk?  How about a crystal ball on the computer industry in the 1960's or 1970's? What if you could have foreseen the Internet?  Well, you're right there again, and this time the
# technology falls under the umbrella of  wireless convergence: data, voice,
# video - and today they all revolve around 802.11 WLAN technology.
# You've got to be on top of the 802.11 engineering issues to be on top in
# technology in the coming years.  Between the covers of this book you' ll find a wealth of information that
# will be a basis for your understanding of wireless data networking, 802.11
# protocol analysis, and WLAN management.  You may find, as I have
# often discovered, that "the more you know, the more you know that you
# don't know", and, at the end of the da y, have fun learning new things and
# never stop challenging yourself.
# -Joseph Bardwell
#
# Chief Scientist and President  of Connect802 Corporation
#
#   Introduction   xxv
#
#  Preface
# First, I would like to thank Criss Hyde for constantly staying on my case
# about details.  This book is all about details, and let me say right now in
# writing that there are lots of them in the 802.11 series of standards.  They
# are written for rocket scientists who have law degrees.  Luckily, Criss is one of those people.
#
# I have learned more technical details while writing this book than I ever wanted to know about anything, ever .  When I began writing this book, I
# only thought
#  I knew this material.  Now, I know enough to know that Ill
# never be able to keep all of it strai ght in my head.  Referencing back to
# the standards from time to time is necessary unless youve opted for
# Google appliance integration surgery.  This whole experience has been mostly  one of learning and re-learning.
# Theres nothing worse than committing something to memory  only to
# find out it is wrong and you have to st art again from scratch.  I have done
# exactly that over and over throughout  the writing (and rewriting) of this
# book.  I equate the current series of 802.11 standards to a mystery novel.  As youre reading, there are many twists and turns, but its not until
# youve read the last page of the last standard that the light comes on in
# your head.  Of course, to be totally honest, you have to read the novel
# (meaning the standards) several times to get the light to come on, and
# even then, the light is somewhat dim at times.  My wish for all of the readers of this book is to suffer less, if only slightly, than I have in learning all of this material.  I cant imagine anything better than having all of the 802.11 facts in one text in a
# digestible format.  Thats what this book is meant to be.  The 802.11
# series of standards is often called the Mother of All Standards.  I think that nickname is very appropriate.  I have trained a great number of the CWNTs out there, and a trait
# common to most of them is constantly asking, How does it work? and
# Why does it work that way?  In  the CWNA and CWSP classes, theres
# a modest amount of answers for those types of questions, but extreme detail is missing due to time constraints.  To some degree, the same is true xxvi   Introduction
#
# of the CWAP class  time is against you all week.  With this book, all of
# the details are here if you can keep them straight in your head.
# Have you ever performed a site survey, security audit, or other common
# WLAN function to realize that something is happening on the network, and you simply do not know why?  In fact, you dont even know where to start looking!  After reading and memorizing this book, you can kiss those days goodbye.  The knowledge youll receive from reading this book will allow you to design, troubleshoot, and test the most complex and
# comprehensive wireless LANs on the market today.  Thats real job
# security for real people in the real world.  Just the other day, a systems engineer from a WLAN product manufacturer asked me, What determines whether or not youre a
# WLAN analyst?  That was a surprisi ngly good question.  My answer was
# a question.  I asked, Have you attempted the CWAP exam yet?
# -Devin Akin
#
# CTO and co-founder of the CWNP Program      Introduction   xxvii
#
#  Introduction
# This official CWAP Study Guide is written for two purposes.  First, the
# book is your indispensable resource for understanding the MAC & PHY frame formatting and frame exchange processes behind every 802.11 wireless LAN.  In other words, you can memorize the 802.11 standard, as well as every addition and amendment to that standard, or you can make
# the CWAP Study Guide a permanent part of your network analysis
# toolkit.  Second, the book is the official self-study resource for helping you prepare for the CWAP exam (PW0-205).  If you are pursuing the CWAP certification, you are required to pass the
# CWNA exam as a pre-requisite.  The knowledge that you will acquire
# through achievement of the CWNA certification will serve as the foundation for learning what has been called, the most technically advanced subject matter currently taught in the IT industry.  If you are reading this book, then you undoubtedly have either a solid
# knowledge of network analysis and ar e now endeavoring to take on the
# wireless end of that trade, or you have earned your CWNA (and possibly
# also CWSP) certification and are ready to take on the next challenge in your wireless LAN-focused career.  Whichever description is more accurate, the outcome will be the same.  You will learn more about the
# technologies that drive 802.11 wireless LANs than you have ever seen
# before.  In addition, you have begun the process of setting yourself further apart from the rest of the IT industry by pushing yourself to learn some of the most complex and technically challenging information in all of IT.  Your study of wireless LAN analysis  will enable you to troubleshoot any
# wireless LAN scenario, improve the performance of any wireless LAN,
# and add a whole new dimension to your ability to secure a wireless LAN.
# Furthermore, because the CWAP curriculum and exam are supported by the industrys leading wireless LAN analysis software makers, you will also have a thorough understanding of how to use all
#  of the leading
# wireless LAN analysis software, whic h software is most appropriate for
# your organization, and which software is best for any given situation.  As a wireless LAN analyst, these skills w ill make you more valuable to your
# organization and to your clients. xxviii   Introduction
# so much support and love and from whom he has learned so much. He would also like to thank Janie, Jennifer, and Samantha for their patience and understanding of life on the road and for their support throughout the writing of this book.
# We must ﬁ  rst thank Sybex acquisitions editor Jeff Kellum for initially ﬁ  nding us and
# bringing us on to this project. Jeff is an extremely patient and understanding editor who has now survived publishing ﬁ  ve books with us. We would also like to thank our develop-
# ment editor, Tom Cirtin. We also need to send special thanks to our editorial manager, Pete Gaughan; our production editor, Christine O’Connor; and Liz Welch, our copyeditor. We also need to give a big shout-out to our technical editor, Marcus Burton of the CWNP program. Marcus, you are the man, dude!
# A special thanks goes to Andrew vonNagy of Revolution Wi-Fi for his feedback and
# content review. We would also like to thank Socrates Sakellaropoulos, Abbey Cole, and Kevin Sandlin of the CWNP program (
# www.cwnp.com ). All CWNP employees,
# past and present, should be proud of the internationally renowned wireless certiﬁ  cation
# program that sets the education standard within the enterprise Wi-Fi industry. It has been a pleasure working with all of you the past decade.
# Thanks to Proxim and to Ken Ruppel (
# kenruppel@gmail.com ) for allowing us to include
# the video Beam  Patterns  and Polarization  of Directional  Antennas  with the book’s online
# resource, which can be accessed at www.sybex.com/go/cwna3e .
# Special thanks goes to Andras Szilagyi for not only creating the EMANIM software
# program but for all the extra assistance he provided over the past six years by creating cus-tomized versions of the program for the different editions of the book.
# We would also like to thank the following individuals and companies for their support
# and contributions to the book:
# Aerohive Networks  (
# www.aerohive.com ) —Devin Akin and Paul Levasseur
# Aruba Networks  (www.arubanetworks.com ) — Carolyn Cutler, Susan Wells, Kevin
# Hamilton, and Chris Leach
# CACE Technologies  (www.cacetech.com ) —Janice Spampinato
# ffirs.indd   vi ffirs.indd   vi 4/10/2012   4:27:29 PM 4/10/2012   4:27:29 PMMetageek (www.metageek.com ) —Mark Jensen and Wendy Fox
# WLAN Professionals  (www.wlanpros.com ) —Keith Parsons
# Welch Allyn (www.welchallyn.com ) —Jeffrey Walker
# Wi-Fi Alliance  (www.wi-fi.org ) —Trisha Campbell and Tom Sciorilli
# ffirs.indd   vii ffirs.indd   vii 4/10/2012   4:27:29 PM 4/10/2012   4:27:29 PMAbout the Authors
# David D. Coleman  is the Global Training Manager for Aerohive Networks,
# www.aerohive.com , creators of  the award-winning cooperative control wireless LAN
# (WLAN) architecture. David is in charge of Aerohive training programs for all partners and customers. David has instructed IT professionals from around the globe in wire-less networking administration, wireless security, and wireless frame analysis. David has written multiple books and white papers about wireless networking and he is considered an authority on 802.11 technology. When he is not traveling, David resides in Atlanta, Georgia. David is CWNE #4 and he can be reached via email at
# mistermultipath@gmail
# .com. You can also follow David online via Twitter at www.twitter.com/mistermultipath .
# David Westcott  is an independent consultant and technical trainer with more than 23 years
# of experience in information technology, specializing in wireless networking and security. In addition to providing advice and direction to corporate clients, David has been a certi-ﬁ ed trainer for more than 19 years, providing training around the world to government
# agencies, corporations, and universities. David has provided training on ﬁ  ve continents
# and in over 40 U.S. states. David was an adjunct faculty member for Boston University’s Corporate Education Center for more than 10 years. David has co-authored ﬁ  ve books
# about wireless networking, and numerous white papers and best practices documents. He has also developed courseware and training videos for clients on wireless networking, wireless mesh networking, wireless packet analysis, wired networking, and security.
# Since installing his ﬁ  rst wireless network in 1999, David has become a Certiﬁ  ed Wireless
# Network Trainer, Administrator, Security Professional, and Analysis Professional. He has earned certiﬁ  cations from Cisco, Aruba Networks, Microsoft, EC-Council, CompTIA, and
# Novell. When not traveling, David lives in Concord, Massachusetts. David is CWNE #7 and can be reached via email at
# david@westcott-consulting.com .
# ffirs.indd   viii ffirs.indd   viii 4/10/2012   4:27:29 PM 4/10/2012   4:27:29 PMContents at a Glance
# Foreword xxvii
# Introduction xxix
# Assessment Test xlviii
# Chapter 1 Overview of Wireless Standards, Organizations, and
# Fundamentals 1
# Chapter 2 Radio Frequency Fundamentals 31
# Chapter 3 Radio Frequency Components, Measurements, and
# Mathematics 63
# Chapter 4 Radio Frequency Signal and Antenna Concepts 103
# Chapter 5 IEEE 802.11 Standards 153
# Chapter 6 Wireless Networks and Spread Spectrum Technologies 189
# Chapter 7 Wireless LAN Topologies 221
# Chapter 8 802.11 Medium Access 247
# Chapter 9 802.11 MAC Architecture 267
# Chapter 10 WLAN Architecture 311
# Chapter 11 WLAN Deployment and Vertical Markets 355
# Chapter 12 WLAN Troubleshooting 379
# Chapter 13 802.11 Network Security Architecture 429
# Chapter 14 Wireless Attacks, Intrusion Monitoring, and Policy 469
# Chapter 15 Radio Frequency Site Survey Fundamentals 503
# Chapter 16 Site Survey Systems and Devices 529
# Chapter 17 Power over Ethernet (PoE) 561
# Chapter 18 High Throughput (HT) and 802.11n 583
# Appendix A Answers to Review Questions 619
# Appendix B Abbreviations, Acronyms, and Regulations 659
# Appendix C About the Additional Study Tools 675
# Index 679
# ffirs.indd   ix ffirs.indd   ix 4/10/2012   4:27:29 PM 4/10/2012   4:27:29 PMffirs.indd   x ffirs.indd   x 4/10/2012   4:27:29 PM 4/10/2012   4:27:29 PMContents
# Foreword xxvii
# Introduction xxix
# Assessment Test xlviii
# Chapter 1 Overview of Wireless Standards, Organizations, and
# --------------------------------------------------------------------------------
# No default IOStream has been set, defaulting to IOConsole.
# No default IOStream has been set, defaulting to IOConsole.
# No default IOStream has been set, defaulting to IOConsole.
# assistant (to ragproxyagent):
#
# It looks like you're looking at the contents of a book on wireless networking! 😊
#
# Here are the contents:
#
# **Foreword**: This is usually an introduction written by someone who has contributed significantly to the field of wireless networking.
#
# **Introduction**: This sets the stage for what's to come in the book. It might provide some background information, explain the purpose and scope of the book, or introduce the authors.
#
# **Assessment Test**: This is a test that readers can use to assess their understanding of the material covered in the book. It could be a quiz or an exam.
#
# **Chapter 1: Overview of Wireless Standards, Organizations, and Fundamentals**: This chapter introduces the reader to the basics of wireless networking, including standards organizations, radio frequency fundamentals, and so on.
#
# **Chapter 2: Radio Frequency Fundamentals**: This chapter delves deeper into the world of radio frequencies, discussing concepts like frequency bands, modulation, and transmission.
#
# **Chapter 3: Radio Frequency Components, Measurements, and Mathematics**: In this chapter, readers will learn about the different components that make up a wireless system (like antennas and amplifiers) and how they're measured and analyzed using mathematical techniques.
#
# **Chapter 4: Radio Frequency Signal and Antenna Concepts**: This chapter covers more advanced topics related to radio frequency signals and antennas, such as beamforming, polarization, and directionality.
#
# **Chapter 5: IEEE 802.11 Standards**: This chapter focuses on the specific standards and protocols used in wireless networking, particularly those developed by the Institute of Electrical and Electronics Engineers (IEEE).
#
# **Chapter 6: Wireless Networks and Spread Spectrum Technologies**: Here, readers will learn about different types of wireless networks (like Wi-Fi and Bluetooth) and spread spectrum technologies that enable them.
#
# **Chapter 7: Wireless LAN Topologies**: This chapter explores the various ways to design and configure a wireless local area network (WLAN), including mesh networks and peer-to-peer connections.
#
# **Chapter 8: 802.11 Medium Access**: In this chapter, readers will learn about how devices access the medium (like the airwaves) in a WLAN, using protocols like CSMA/CA and DCF.
#
# **Chapter 9: 802.11 MAC Architecture**: This chapter delves into the architecture of the medium access control (MAC) layer in 802.11, which is responsible for managing data transmission and reception.
#
# **Chapter 10: WLAN Architecture**: Here, readers will learn about the different components that make up a WLAN, including the MAC layer, physical layer, and network layers.
#
# **Chapter 11: WLAN Deployment and Vertical Markets**: This chapter covers how to deploy WLANs in different environments (like hospitals or campuses) and explores various vertical markets that use wireless networking.
#
# **Chapter 12: WLAN Troubleshooting**: In this chapter, readers will learn about the common problems that can occur with WLANs and how to troubleshoot them using tools like sniffers and protocol analyzers.
#
# **Chapter 13: 802.11 Network Security Architecture**: This chapter focuses on the security aspects of WLANs, including authentication, authorization, and encryption (AAA).
#
# **Chapter 14: Wireless Attacks, Intrusion Monitoring, and Policy**: Here, readers will learn about different types of wireless attacks (like hacking and eavesdropping) and how to monitor for intrusions and develop policies to prevent them.
#
# **Chapter 15: Radio Frequency Site Survey Fundamentals**: This chapter covers the basics of radio frequency (RF) site surveys, which are used to plan and optimize WLAN deployments.
#
# **Chapter 16: Site Survey Systems and Devices**: In this chapter, readers will learn about different types of site survey systems and devices that
#
#
#
# --------------------------------------------------------------------------------
# No default IOStream has been set, defaulting to IOConsole.
# No default IOStream has been set, defaulting to IOConsole.
# Please give feedback to assistant. Press enter or type 'exit' to stop the conversation: exit
# ChatResult(chat_id=None, chat_history=[{'content': 'You\'re a retrieve augmented chatbot. You answer user\'s questions based on your own knowledge and the\ncontext provided by the user.\nIf you can\'t answer the question with or without the current context, you should reply exactly `UPDATE CONTEXT`.\nYou must give as short an answer as possible.\n\nUser\'s question is: hi how are you feeling today\n\nContext is:  \nThere are very few times in the course of human history when it\'s been evident that a new technology would dramatically change the way society functions.  What if you knew where the automotive industry was heading when Carl Benz championed the internal combustion engine in his 3-\nwheeled car in 1885.  What if yo u could have foreseen the aviation \nindustry when the Wright\'s flew at Kitty Hawk?  How about a crystal ball on the computer industry in the 1960\'s or 1970\'s? What if you could have foreseen the Internet?  Well, you\'re right there again, and this time the \ntechnology falls under the umbrella of  wireless convergence: data, voice, \nvideo - and today they all revolve around 802.11 WLAN technology.  \nYou\'ve got to be on top of the 802.11 engineering issues to be on top in \ntechnology in the coming years.  Between the covers of this book you\' ll find a wealth of information that \nwill be a basis for your understanding of wireless data networking, 802.11 \nprotocol analysis, and WLAN management.  You may find, as I have \noften discovered, that "the more you know, the more you know that you \ndon\'t know", and, at the end of the da y, have fun learning new things and \nnever stop challenging yourself.  \n-Joseph Bardwell \n \nChief Scientist and President  of Connect802 Corporation \n \n  Introduction   xxv \n \n Preface \nFirst, I would like to thank Criss Hyde for constantly staying on my case \nabout details.  This book is all about details, and let me say right now in \nwriting that there are lots of them in the 802.11 series of standards.  They \nare written for rocket scientists who have law degrees.  Luckily, Criss is one of those people.   \n \nI have learned more technical details while writing this book than I ever wanted to know about anything, ever .  When I began writing this book, I \nonly thought\n I knew this material.  Now, I know enough to know that I\x92ll \nnever be able to keep all of it strai ght in my head.  Referencing back to \nthe standards from time to time is necessary unless you\x92ve opted for \nGoogle appliance integration surgery.  This whole experience has been mostly  one of learning and re-learning.  \nThere\x92s nothing worse than committing something to memory \x96 only to \nfind out it is wrong and you have to st art again from scratch.  I have done \nexactly that over and over throughout  the writing (and rewriting) of this \nbook.  I equate the current series of 802.11 standards to a mystery novel.  As you\x92re reading, there are many twists and turns, but it\x92s not until \nyou\x92ve read the last page of the last standard that the light comes on in \nyour head.  Of course, to be totally honest, you have to read the novel \n(meaning the standards) several times to get the light to come on, and \neven then, the light is somewhat dim at times.  My wish for all of the readers of this book is to suffer less, if only slightly, than I have in learning all of this material.  I can\x92t imagine anything better than having all of the 802.11 facts in one text in a \ndigestible format.  That\x92s what this book is meant to be.  The 802.11 \nseries of standards is often called the \x93Mother of All Standards.\x94  I think that nickname is very appropriate.  I have trained a great number of the CWNTs out there, and a trait \ncommon to most of them is constantly asking, \x93How does it work?\x94 and \n\x93Why does it work that way?\x94  In  the CWNA and CWSP classes, there\x92s \na modest amount of answers for those types of questions, but extreme detail is missing due t ...
